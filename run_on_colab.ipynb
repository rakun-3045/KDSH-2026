# %% [markdown]
# # Run KDSH 2026 on Google Colab
#
# This notebook helps you run the Narrative Consistency project on Google Colab.
#
# ### Prerequisites
# 1. Upload the entire `KDSH 2026` project folder to your Google Drive.
#    (Recommended location: `My Drive/KDSH 2026`)
# 2. Configure your API Keys in Google Colab Secrets (Key icon in the left sidebar):
#    - `GROQ_API_KEY`
#    - `GOOGLE_API_KEY`
#    - `HUGGINGFACE_API_KEY`

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Navigate to Project Folder
import os

# Update this path if you uploaded it somewhere else
project_path = '/content/drive/My Drive/KDSH 2026' 

if os.path.exists(project_path):
    os.chdir(project_path)
    print(f"Successfully changed directory to: {os.getcwd()}")
else:
    print(f"Error: Path not found: {project_path}")
    print("Please verify where you uploaded the 'KDSH 2026' folder in Google Drive.")

# %%
# 3. Install Dependencies
print("Installing dependencies...")
# !pip install -r requirements.txt
# !pip install -U pathway
print("Installation complete.")

# %%
# 4. Configure API Keys
from google.colab import userdata
import os

# Try to load from Colab Secrets
try:
    os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
    print("Loaded GROQ_API_KEY")
except Exception:
    print("GROQ_API_KEY not found in Secrets")

try:
    os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')
    print("Loaded GOOGLE_API_KEY")
except Exception:
    print("GOOGLE_API_KEY not found in Secrets")

# Optional: Set manually if needed
# os.environ["GOOGLE_API_KEY"] = "AIza..."

# %%
# 5. Run the Pipeline
# Mode choices: 'train', 'predict', 'full'
# LLM choices: 'gemini-1.5-flash', 'openai/gpt-4o', etc.

# !python main.py --mode predict --llm-model "gemini-2.0-flash-exp"
